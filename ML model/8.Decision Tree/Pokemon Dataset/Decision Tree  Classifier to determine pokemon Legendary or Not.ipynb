# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('pokemon.csv')

# %% [markdown]
# ## EDA

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.shape
# Out:
# (801, 41)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.rename(columns={'Type 1':'Primary','Type 2':'Secondary'},inplace=True)

# %%
df.Primary.value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Primary, dtype: int64

# %%
grass_pokemon=df[df['Primary']=='Grass']

# %%
grass_pokemon.shape
# Out:
# (70, 13)

# %%
water_pokemon=df[df['Primary']=='Water']

# %%
water_pokemon
# Out:
#        #                     Name Primary Secondary  Total  HP  Attack  \
# 9      7                 Squirtle   Water       NaN    314  44      48
# 10     8                Wartortle   Water       NaN    405  59      63
# 11     9                Blastoise   Water       NaN    530  79      83
# 12     9  BlastoiseMega Blastoise   Water       NaN    630  79     103
# 59    54                  Psyduck   Water       NaN    320  50      52
# ..   ...                      ...     ...       ...    ...  ..     ...
# 724  656                  Froakie   Water       NaN    314  41      56
# 725  657                Frogadier   Water       NaN    405  54      63
# 726  658                 Greninja   Water      Dark    530  72      95
# 762  692                Clauncher   Water       NaN    330  50      53
# 763  693                Clawitzer   Water       NaN    500  71      73
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
water_pokemon.shape
# Out:
# (112, 13)

# %%
rock_pokemon=df[df['Primary']=='Rock']

# %%
rock_pokemon.shape
# Out:
# (44, 13)

# %%
fire_pokemon=df[df['Primary']=='Fire']

# %%
fire_pokemon.head()
# Out:
#    #                       Name Primary Secondary  Total  HP  Attack  Defense  \
# 4  4                 Charmander    Fire       NaN    309  39      52       43
# 5  5                 Charmeleon    Fire       NaN    405  58      64       58
# 6  6                  Charizard    Fire    Flying    534  78      84       78
# 7  6  CharizardMega Charizard X    Fire    Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y    Fire    Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False

# %%
fire_pokemon.shape
# Out:
# (52, 13)

# %%
electric_pokemon=df[df['Primary']=='Electric']

# %%
electric_pokemon
# Out:
#        #                      Name   Primary Secondary  Total  HP  Attack  \
# 30    25                   Pikachu  Electric       NaN    320  35      55
# 31    26                    Raichu  Electric       NaN    485  60      90
# 88    81                 Magnemite  Electric     Steel    325  25      35
# 89    82                  Magneton  Electric     Steel    465  50      60
# 108  100                   Voltorb  Electric       NaN    330  40      30
# 109  101                 Electrode  Electric       NaN    480  60      50
# 134  125                Electabuzz  Electric       NaN    490  65      83
# 146  135                   Jolteon  Electric       NaN    525  65      65
# 157  145                    Zapdos  Electric    Flying    580  90      90
# 186  172                     Pichu  Electric       NaN    205  20      40
# 193  179                    Mareep  Electric       NaN    280  55      40
# 194  180                   Flaaffy  Electric       NaN    365  70      55
# ...

# %%
df.shape
# Out:
# (800, 13)

# %%
grass_pokemon.shape
# Out:
# (70, 13)

# %%
water_pokemon.shape
# Out:
# (112, 13)

# %%
fire_pokemon.shape
# Out:
# (52, 13)

# %%
electric_pokemon.shape
# Out:
# (44, 13)

# %%
#Anlysis on Grass Pokemon
grass_pokemon.shape
# Out:
# (70, 13)

# %%
sns.histplot(grass_pokemon['Speed'])
# Out:
# <AxesSubplot:xlabel='Speed', ylabel='Count'>

# %%
sns.histplot(grass_pokemon['Sp. Atk'])
# Out:
# <AxesSubplot:xlabel='Sp. Atk', ylabel='Count'>

# %%
sns.histplot(grass_pokemon['Sp. Def'])
# Out:
# <AxesSubplot:xlabel='Sp. Def', ylabel='Count'>

# %% [markdown]
# ### Grass Type pokemon have better attack but not defence

# %%
grass_pokemon.describe()
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count   70.000000   70.000000   70.000000   70.000000   70.000000   70.000000
# mean   344.871429  421.142857   67.271429   73.214286   70.800000   77.500000
# std    200.264385  106.650626   19.516564   25.380520   24.485192   27.244864
# min      1.000000  180.000000   30.000000   27.000000   30.000000   24.000000
# 25%    187.250000  318.500000   51.250000   55.000000   50.000000   57.000000
# 50%    372.000000  430.000000   65.500000   70.000000   66.000000   75.000000
# 75%    496.750000  497.000000   75.000000   93.500000   84.500000   99.500000
# max    673.000000  630.000000  123.000000  132.000000  131.000000  145.000000
#
#           Sp. Def       Speed  Generation
# count   70.000000   70.000000   70.000000
# mean    70.428571   61.928571    3.357143
# std     21.446645   28.506456    1.579173
# min     30.000000   10.000000    1.000000
# 25%     55.000000   40.000000    2.000000
# ...

# %%
#Anlysis on Water Pokemon
water_pokemon
# Out:
#        #                     Name Primary Secondary  Total  HP  Attack  \
# 9      7                 Squirtle   Water       NaN    314  44      48
# 10     8                Wartortle   Water       NaN    405  59      63
# 11     9                Blastoise   Water       NaN    530  79      83
# 12     9  BlastoiseMega Blastoise   Water       NaN    630  79     103
# 59    54                  Psyduck   Water       NaN    320  50      52
# ..   ...                      ...     ...       ...    ...  ..     ...
# 724  656                  Froakie   Water       NaN    314  41      56
# 725  657                Frogadier   Water       NaN    405  54      63
# 726  658                 Greninja   Water      Dark    530  72      95
# 762  692                Clauncher   Water       NaN    330  50      53
# 763  693                Clawitzer   Water       NaN    500  71      73
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
sns.histplot(water_pokemon['Speed'])
plt.subplot(2,2,2)
sns.histplot(water_pokemon['Sp. Atk'])
plt.subplot(2,2,3)
sns.histplot(water_pokemon['Sp. Def'])
plt.show()

# %%
water_pokemon.describe()
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count  112.000000  112.000000  112.000000  112.000000  112.000000  112.000000
# mean   303.089286  430.455357   72.062500   74.151786   72.946429   74.812500
# std    188.440807  113.188266   27.487026   28.377192   27.773809   29.030128
# min      7.000000  200.000000   20.000000   10.000000   20.000000   10.000000
# 25%    130.000000  328.750000   52.250000   53.000000   54.500000   55.000000
# 50%    275.000000  455.000000   70.000000   72.000000   70.000000   70.000000
# 75%    456.250000  502.250000   90.250000   92.000000   88.500000   90.500000
# max    693.000000  770.000000  170.000000  155.000000  180.000000  180.000000
#
#           Sp. Def       Speed  Generation
# count  112.000000  112.000000  112.000000
# mean    70.517857   65.964286    2.857143
# std     28.460493   23.019353    1.558800
# min     20.000000   15.000000    1.000000
# 25%     50.000000   50.000000    1.000000
# ...

# %%
#analysis on fire type Pokemon
fire_pokemon
# Out:
#        #                       Name Primary Secondary  Total   HP  Attack  \
# 4      4                 Charmander    Fire       NaN    309   39      52
# 5      5                 Charmeleon    Fire       NaN    405   58      64
# 6      6                  Charizard    Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X    Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y    Fire    Flying    634   78     104
# 42    37                     Vulpix    Fire       NaN    299   38      41
# 43    38                  Ninetales    Fire       NaN    505   73      76
# 63    58                  Growlithe    Fire       NaN    350   55      70
# 64    59                   Arcanine    Fire       NaN    555   90     110
# 83    77                     Ponyta    Fire       NaN    410   50      85
# 84    78                   Rapidash    Fire       NaN    500   65     100
# 135  126                     Magmar    Fire       NaN    495   65      95
# ...

# %%
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
sns.histplot(fire_pokemon['Speed'])
plt.subplot(2,2,2)
sns.histplot(fire_pokemon['Sp. Atk'])
plt.subplot(2,2,3)
sns.histplot(fire_pokemon['Sp. Def'])
plt.show()

# %%
fire_pokemon.describe()
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count   52.000000   52.000000   52.000000   52.000000   52.000000   52.000000
# mean   327.403846  458.076923   69.903846   84.769231   67.769231   88.980769
# std    226.262840  109.760496   19.404123   28.769275   23.658200   30.042121
# min      4.000000  250.000000   38.000000   30.000000   37.000000   15.000000
# 25%    143.500000  368.000000   58.000000   62.250000   51.000000   70.000000
# 50%    289.500000  482.000000   70.000000   84.500000   64.000000   85.000000
# 75%    513.250000  534.000000   80.000000  101.000000   78.000000  109.000000
# max    721.000000  680.000000  115.000000  160.000000  140.000000  159.000000
#
#           Sp. Def       Speed  Generation
# count   52.000000   52.000000   52.000000
# mean    72.211538   74.442308    3.211538
# std     22.619908   25.245783    1.850665
# min     40.000000   20.000000    1.000000
# 25%     54.750000   60.000000    1.000000
# ...

# %%
#Analysis on Rock type pokemon
rock_pokemon
# Out:
#        #                       Name Primary Secondary  Total   HP  Attack  \
# 80    74                    Geodude    Rock    Ground    300   40      80
# 81    75                   Graveler    Rock    Ground    390   55      95
# 82    76                      Golem    Rock    Ground    495   80     120
# 103   95                       Onix    Rock    Ground    385   35      45
# 149  138                    Omanyte    Rock     Water    355   35      40
# 150  139                    Omastar    Rock     Water    495   70      60
# 151  140                     Kabuto    Rock     Water    355   30      80
# 152  141                   Kabutops    Rock     Water    495   60     115
# 153  142                 Aerodactyl    Rock    Flying    515   80     105
# 154  142  AerodactylMega Aerodactyl    Rock    Flying    615   80     135
# 200  185                  Sudowoodo    Rock       NaN    410   70     100
# 265  246                   Larvitar    Rock    Ground    300   50      64
# ...

# %%
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
sns.histplot(rock_pokemon['Speed'])
plt.subplot(2,2,2)
sns.histplot(rock_pokemon['Sp. Atk'])
plt.subplot(2,2,3)
sns.histplot(rock_pokemon['Sp. Def'])
plt.show()

# %%
rock_pokemon.describe()
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count   44.000000   44.000000   44.000000   44.000000   44.000000   44.000000
# mean   392.727273  453.750000   65.363636   92.863636  100.795455   63.340909
# std    213.746140  108.059227   20.833884   35.325458   36.447209   28.249670
# min     74.000000  280.000000   30.000000   40.000000   40.000000   10.000000
# 25%    230.750000  360.250000   50.000000   59.750000   71.500000   45.000000
# 50%    362.500000  467.500000   68.500000   95.000000  100.000000   60.000000
# 75%    566.250000  516.500000   80.000000  120.250000  120.500000   74.250000
# max    719.000000  700.000000  123.000000  165.000000  200.000000  160.000000
#
#           Sp. Def       Speed  Generation
# count   44.000000   44.000000   44.000000
# mean    75.477273   55.909091    3.454545
# std     32.265965   29.903580    1.848375
# min     25.000000   10.000000    1.000000
# 25%     50.000000   35.000000    2.000000
# ...

# %%
#Analysis on the Electric Type Pokemon

# %%
electric_pokemon
# Out:
#        #                      Name   Primary Secondary  Total  HP  Attack  \
# 30    25                   Pikachu  Electric       NaN    320  35      55
# 31    26                    Raichu  Electric       NaN    485  60      90
# 88    81                 Magnemite  Electric     Steel    325  25      35
# 89    82                  Magneton  Electric     Steel    465  50      60
# 108  100                   Voltorb  Electric       NaN    330  40      30
# 109  101                 Electrode  Electric       NaN    480  60      50
# 134  125                Electabuzz  Electric       NaN    490  65      83
# 146  135                   Jolteon  Electric       NaN    525  65      65
# 157  145                    Zapdos  Electric    Flying    580  90      90
# 186  172                     Pichu  Electric       NaN    205  20      40
# 193  179                    Mareep  Electric       NaN    280  55      40
# 194  180                   Flaaffy  Electric       NaN    365  70      55
# ...

# %%
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
sns.histplot(electric_pokemon['Speed'])
plt.subplot(2,2,2)
sns.histplot(electric_pokemon['Sp. Atk'])
plt.subplot(2,2,3)
sns.histplot(electric_pokemon['Sp. Def'])
plt.show()

# %%
electric_pokemon.describe()
# Out:
#                 #       Total         HP      Attack     Defense     Sp. Atk  \
# count   44.000000   44.000000  44.000000   44.000000   44.000000   44.000000
# mean   363.500000  443.409091  59.795455   69.090909   66.295455   90.022727
# std    202.731063  105.721952  17.306511   23.764169   24.757033   29.740340
# min     25.000000  205.000000  20.000000   30.000000   15.000000   35.000000
# 25%    179.750000  362.250000  50.000000   53.750000   49.750000   65.000000
# 50%    403.500000  477.500000  60.000000   65.000000   65.000000   95.000000
# 75%    489.750000  520.000000  70.000000   85.000000   80.000000  106.000000
# max    702.000000  610.000000  90.000000  123.000000  115.000000  165.000000
#
#           Sp. Def       Speed  Generation
# count   44.000000   44.000000   44.000000
# mean    73.704545   84.500000    3.272727
# std     22.601275   26.691607    1.604697
# min     32.000000   35.000000    1.000000
# 25%     55.000000   60.000000    2.000000
# ...

# %%
df.Generation.value_counts()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %% [markdown]
# ## Determine Dependent variable and Independent Variable

# %%
x=df[['Speed','Sp. Atk','Sp. Def']]

# %%
y=df[['Legendary']]

# %%
#Spliting the data set
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (640, 3)

# %%
X_test.shape
# Out:
# (160, 3)

# %%
x.shape
# Out:
# (800, 3)

# %% [markdown]
# ## model training

# %%
#model training
from sklearn.tree import DecisionTreeClassifier

# %%
model1=DecisionTreeClassifier()

# %%
model1.fit(X_test,y_test)
# Out:
# DecisionTreeClassifier()

# %%
model1.predict([[140,60,70]])
# Out:
# array([False])

# %%
y_pred=model1.predict(X_test)

# %%
y_pred
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False,  True,  True, False, False,
#        False, False, False,  True, False, False, False,  True, False,
#        False, False, False,  True, False, False, False, False, False,
#        False,  True,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False,  True,  True,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
# ...

# %%
y_test
# Out:
#      Legendary
# 55       False
# 503      False
# 232      False
# 97       False
# 686      False
# ..         ...
# 291      False
# 33       False
# 69       False
# 637      False
# 633      False
#
# [160 rows x 1 columns]

# %%
model1.score(X_test,y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[143,   0],
#        [  0,  17]], dtype=int64)

# %%
(143+17)/(0+143+17+0)
# Out:
# 1.0

# %% [markdown]
# ## Saving the Model

# %%
import joblib

# %%
joblib.dump(model1,open('legendary_model.joblib','wb'))
